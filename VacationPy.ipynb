# %%
# import our dependencies
import pandas as pd
import gmaps
import requests 
# Import the API key.
from config2 import g_key

# %%
file_to_load = "weather_data/cities.csv"
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv(file_to_load)
city_data_df.head(10)
# Out:
#    City ID             City Country                 Date    Lat     Lng  \
# 0        0           Dikson      RU  2020-10-25 02:57:45  73.51   80.55
# 1        1            Alofi      NU  2020-10-25 02:59:00 -19.06 -169.92
# 2        2          Rikitea      PF  2020-10-25 02:57:26 -23.12 -134.97
# 3        3        Nantucket      US  2020-10-25 02:58:25  41.28  -70.10
# 4        4  Arraial Do Cabo      BR  2020-10-25 02:58:05 -22.97  -42.03
# 5        5          Chibuto      MZ  2020-10-25 03:02:55 -24.69   33.53
# 6        6             Hilo      US  2020-10-25 03:02:24  19.73 -155.09
# 7        7        Ilulissat      GL  2020-10-25 02:59:16  69.22  -51.10
# 8        8           Ossora      RU  2020-10-25 03:02:55  59.24  163.07
# 9        9           Atuona      PF  2020-10-25 03:02:55  -9.80 -139.03
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     21.87        92          38        6.58
# 1     80.60        78          94       17.22
# 2     74.88        82          97       20.71
# 3     57.99        85          90       17.22
# 4     69.98        92         100       21.94
# 5     64.18        99           3        1.36
# 6     82.40        69          75       12.75
# 7     19.40        57           3        6.93
# 8     41.47        82         100       10.11
# 9     78.66        75          30       20.56

# %%
city_data_df.dtypes
# Out:
# City ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
max_temp = city_data_df["Max Temp"]
new_max_temp = [max(temp,0) for temp in max_temp]
# 3. Assign the figure variable to the gmaps.figure() attribute.
fig = gmaps.figure()
# Assign the heatmap variable
heat_layer = gmaps.heatmap_layer(locations, weights=new_max_temp)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
max_temp = city_data_df["Max Temp"]
new_max_temp = [max(temp,0) for temp in max_temp]
# 3. Assign the figure variable to the gmaps.figure() attribute.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable
heat_layer = gmaps.heatmap_layer(locations, weights=new_max_temp, dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of Cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of Wind speed
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 78
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)].dropna()
preferred_cities_df
# Out:
#      City ID         City Country                 Date    Lat     Lng  \
# 1          1        Alofi      NU  2020-10-25 02:59:00 -19.06 -169.92
# 6          6         Hilo      US  2020-10-25 03:02:24  19.73 -155.09
# 9          9       Atuona      PF  2020-10-25 03:02:55  -9.80 -139.03
# 14        14        Buala      SB  2020-10-25 03:02:57  -8.14  159.59
# 22        22        Kapaa      US  2020-10-25 02:57:32  22.08 -159.32
# ..       ...          ...     ...                  ...    ...     ...
# 535      535  Port-Gentil      GA  2020-10-25 02:57:51  -0.72    8.78
# 539      539   The Valley      AI  2020-10-25 03:01:37  18.22  -63.06
# 542      542      Samarai      PG  2020-10-25 03:04:48 -10.62  150.67
# 546      546       Canton      CN  2020-10-25 03:00:18  23.12  113.25
# 553      553  Terra Santa      BR  2020-10-25 03:04:32  -2.10  -56.49
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 1       80.60        78          94       17.22
# 6       82.40        69          75       12.75
# 9       78.66        75          30       20.56
# 14      85.37        71          52        5.10
# 22      82.40        69          40       14.99
# ..        ...       ...         ...         ...
# 535     78.28        84         100       13.71
# 539     84.20        70          40       12.75
# 542     81.77        79          72        6.69
# 546     84.00        36          75        4.47
# 553     78.01        67          89        3.44
#
# [120 rows x 10 columns]

# %%
preferred_cities_df.count()
# Out:
# City ID       120
# City          120
# Country       120
# Date          120
# Lat           120
# Lng           120
# Max Temp      120
# Humidity      120
# Cloudiness    120
# Wind Speed    120
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#              City Country  Max Temp    Lat     Lng Hotel Name
# 1           Alofi      NU     80.60 -19.06 -169.92
# 6            Hilo      US     82.40  19.73 -155.09
# 9          Atuona      PF     78.66  -9.80 -139.03
# 14          Buala      SB     85.37  -8.14  159.59
# 22          Kapaa      US     82.40  22.08 -159.32
# 35  Makakilo City      US     84.20  21.35 -158.09
# 38          Soure      BR     80.10  -0.72  -48.52
# 45         Dingle      PH     81.52  11.00  122.67
# 47         Faanui      PF     79.39 -16.48 -151.75
# 48      Hithadhoo      MV     83.28  -0.60   73.08

# %%
# Set parameters to search for a hotel.
parameters = { "radius": 5000,
               "type" : "lodging",
               "key"  : g_key
    
}

# %%
# Iterate through the DataFrame.
for index,row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"] 
    lng = row["Lng"]
    
    # Add the latitude and longitude to location key for the params dictionary.
    parameters["location"] = f"{lat},{lng}"
    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=parameters).json()
    try:
        # Grab the first hotel from the results and store the name.
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except IndexError:
        print("Hotel name not found, Skipping")
# Out:
# Hotel name not found, Skipping
# Hotel name not found, Skipping
# Hotel name not found, Skipping
# Hotel name not found, Skipping
# Hotel name not found, Skipping
# Hotel name not found, Skipping
# Hotel name not found, Skipping

# %%
hotel_df
# Out:
#             City Country  Max Temp    Lat     Lng  \
# 1          Alofi      NU     80.60 -19.06 -169.92
# 6           Hilo      US     82.40  19.73 -155.09
# 9         Atuona      PF     78.66  -9.80 -139.03
# 14         Buala      SB     85.37  -8.14  159.59
# 22         Kapaa      US     82.40  22.08 -159.32
# ..           ...     ...       ...    ...     ...
# 535  Port-Gentil      GA     78.28  -0.72    8.78
# 539   The Valley      AI     84.20  18.22  -63.06
# 542      Samarai      PG     81.77 -10.62  150.67
# 546       Canton      CN     84.00  23.12  113.25
# 553  Terra Santa      BR     78.01  -2.10  -56.49
#
#                                  Hotel Name
# 1                             Taloa Heights
# 6                       Hilo Hawaiian Hotel
# 9                               Villa Enata
# 14                     Maringe Lagoon Lodge
# 22   Sheraton Kauai Resort at Coconut Beach
# ..                                      ...
# 535                      Fengshui Residence
# 539            CeBlue Villas & Beach Resort
# 542                               Nuli Sapi
# 546                         Guangzhou Hotel
# 553                           Igreja da paz
#
# [120 rows x 6 columns]

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
hotel_info
# Out:
# ['\n<dl>\n<dt>Hotel Name</dt><dd>Taloa Heights</dd>\n<dt>City</dt><dd>Alofi</dd>\n<dt>Country</dt><dd>NU</dd>\n<dt>Max Temp</dt><dd>80.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hilo Hawaiian Hotel</dd>\n<dt>City</dt><dd>Hilo</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>82.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Villa Enata</dd>\n<dt>City</dt><dd>Atuona</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>78.66 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Maringe Lagoon Lodge</dd>\n<dt>City</dt><dd>Buala</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Max Temp</dt><dd>85.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sheraton Kauai Resort at Coconut Beach</dd>\n<dt>City</dt><dd>Kapaa</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>82.4 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Marriott's Ko Olina Beach Club</dd>\n<dt>City</dt><dd>Makakilo City</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>84.2 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Marajó</dd>\n<dt>City</dt><dd>Soure</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>80.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Camp Pasica</dd>\n<dt>City</dt><dd>Dingle</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>81.52 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Bora-Bora Pearl Beach Resort & Spa</dd>\n<dt>City</dt><dd>Faanui</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>79.39 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Scoop Guest House</dd>\n<dt>City</dt><dd>Hithadhoo</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Max Temp</dt><dd>83.28 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Grage Hotel Bengkulu</dd>\n<dt>City</dt><dd>Bengkulu</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>84.43 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Isles Sunset Lodge</dd>\n<dt>City</dt><dd>Butaritari</dd>\n<dt>Country</dt><dd>KI</dd>\n<dt>Max Temp</dt><dd>81.14 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Maia's Beach Resort</dd>\n<dt>City</dt><dd>Sulangan</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>81.1 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tortuga B&B</dd>\n<dt>City</dt><dd>Sao Filipe</dd>\n<dt>Country</dt><dd>CV</dd>\n<dt>Max Temp</dt><dd>81.27 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nusa Island Retreat</dd>\n<dt>City</dt><dd>Kavieng</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>85.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>International Lodge Motel</dd>\n<dt>City</dt><dd>Mackay</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>84.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Cititel Penang</dd>\n<dt>City</dt><dd>Georgetown</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Max Temp</dt><dd>84.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Piesta</dd>\n<dt>City</dt><dd>Trinidad</dd>\n<dt>Country</dt><dd>BO</dd>\n<dt>Max Temp</dt><dd>85.69 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>ibis Styles Mt Isa Verona</dd>\n<dt>City</dt><dd>Mount Isa</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>84.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Orós</dd>\n<dt>City</dt><dd>Oros</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>79.41 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Edi</dd>\n<dt>City</dt><dd>Ciudad Bolivar</dd>\n<dt>Country</dt><dd>VE</dd>\n<dt>Max Temp</dt><dd>78.94 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Adrar</dd>\n<dt>Country</dt><dd>MR</dd>\n<dt>Max Temp</dt><dd>84.27 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Puri Brata</dd>\n<dt>City</dt><dd>Bambanglipuro</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>83.66 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mercure Padang</dd>\n<dt>City</dt><dd>Padang</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>82.35 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lorengau Harbourside Hotel</dd>\n<dt>City</dt><dd>Lorengau</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>86.31 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Divi Village Golf & Beach Resort</dd>\n<dt>City</dt><dd>Oranjestad</dd>\n<dt>Country</dt><dd>AW</dd>\n<dt>Max Temp</dt><dd>84.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Heritage Park Hotel</dd>\n<dt>City</dt><dd>Honiara</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Max Temp</dt><dd>87.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>MD SHOYAB Girni</dd>\n<dt>City</dt><dd>Jevargi</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>79.09 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pension Oaoa</dd>\n<dt>City</dt><dd>Tautira</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>80.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Juvinal Martin</dd>\n<dt>City</dt><dd>Airai</dd>\n<dt>Country</dt><dd>TL</dd>\n<dt>Max Temp</dt><dd>81.3 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Gran Lençóis Flat Residence</dd>\n<dt>City</dt><dd>Barreirinhas</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>81.09 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Guest Hotel</dd>\n<dt>City</dt><dd>Manggar</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>84.78 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Amazônia Center</dd>\n<dt>City</dt><dd>Obidos</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>80.53 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Whispering Bamboo Cove Resort</dd>\n<dt>City</dt><dd>Morant Bay</dd>\n<dt>Country</dt><dd>JM</dd>\n<dt>Max Temp</dt><dd>82.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotels in Lakshadweep Islands</dd>\n<dt>City</dt><dd>Kavaratti</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>81.81 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Tesoro Los Cabos</dd>\n<dt>City</dt><dd>Cabo San Lucas</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>81.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Kieta</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>84.29 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mini Hotel Central</dd>\n<dt>City</dt><dd>Victoria</dd>\n<dt>Country</dt><dd>HK</dd>\n<dt>Max Temp</dt><dd>78.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>VS Villa</dd>\n<dt>City</dt><dd>Kalmunai</dd>\n<dt>Country</dt><dd>LK</dd>\n<dt>Max Temp</dt><dd>84.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Bungalow 63</dd>\n<dt>City</dt><dd>Hambantota</dd>\n<dt>Country</dt><dd>LK</dd>\n<dt>Max Temp</dt><dd>82.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Big Fish Guest House</dd>\n<dt>City</dt><dd>Corn Island</dd>\n<dt>Country</dt><dd>NI</dd>\n<dt>Max Temp</dt><dd>83.19 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mrs Luis Guest House</dd>\n<dt>City</dt><dd>Lampang</dd>\n<dt>Country</dt><dd>TH</dd>\n<dt>Max Temp</dt><dd>82.99 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Erlyn’s Sta Rosa City Home</dd>\n<dt>City</dt><dd>Santa Rosa</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>84.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mantra Towers of Chevron Surfers Paradise</dd>\n<dt>City</dt><dd>Gold Coast</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>82.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Posada San Jose</dd>\n<dt>City</dt><dd>Pochutla</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>80.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Atlantis Hotel</dd>\n<dt>City</dt><dd>Bathsheba</dd>\n<dt>Country</dt><dd>BB</dd>\n<dt>Max Temp</dt><dd>82.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ramada Hotel & Suites by Wyndham Ballina Byron</dd>\n<dt>City</dt><dd>Ballina</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>84.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Kandrian Station</dd>\n<dt>City</dt><dd>Kandrian</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>86.5 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Esplanade Hotel</dd>\n<dt>City</dt><dd>Port Hedland</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>82.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Auberge’Inn</dd>\n<dt>City</dt><dd>Jeremie</dd>\n<dt>Country</dt><dd>HT</dd>\n<dt>Max Temp</dt><dd>80.31 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shelly Bay Resort</dd>\n<dt>City</dt><dd>Hervey Bay</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>78.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sun City Restaurant</dd>\n<dt>City</dt><dd>Qiongshan</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Max Temp</dt><dd>78.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sumayang Property</dd>\n<dt>City</dt><dd>Bacungan</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>82.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Irish Village</dd>\n<dt>City</dt><dd>Emerald</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>82.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Obelisco</dd>\n<dt>City</dt><dd>Cobija</dd>\n<dt>Country</dt><dd>BO</dd>\n<dt>Max Temp</dt><dd>79.02 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Playa Bonita</dd>\n<dt>City</dt><dd>Limon</dd>\n<dt>Country</dt><dd>CR</dd>\n<dt>Max Temp</dt><dd>80.76 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Amarração</dd>\n<dt>City</dt><dd>Luis Correia</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>78.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Puro</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>82.78 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Volcano Sea View Tree House</dd>\n<dt>City</dt><dd>Isangel</dd>\n<dt>Country</dt><dd>VU</dd>\n<dt>Max Temp</dt><dd>84.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Siesta Hotel</dd>\n<dt>City</dt><dd>Saint-Georges</dd>\n<dt>Country</dt><dd>GD</dd>\n<dt>Max Temp</dt><dd>82.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hostal Rio Miel</dd>\n<dt>City</dt><dd>Baracoa</dd>\n<dt>Country</dt><dd>CU</dd>\n<dt>Max Temp</dt><dd>79.47 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Auberge les abou</dd>\n<dt>City</dt><dd>Fomboni</dd>\n<dt>Country</dt><dd>KM</dd>\n<dt>Max Temp</dt><dd>79.72 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Enon Beach Resort</dd>\n<dt>City</dt><dd>Buluang</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>84.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Haajy Guest House 1</dd>\n<dt>City</dt><dd>Kulhudhuffushi</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Max Temp</dt><dd>82.78 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Kost Ariz</dd>\n<dt>City</dt><dd>Biak</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>84.92 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Swiss Belhotel Manokwari</dd>\n<dt>City</dt><dd>Manokwari</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>84.38 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ulkel Guest House</dd>\n<dt>City</dt><dd>Sola</dd>\n<dt>Country</dt><dd>VU</dd>\n<dt>Max Temp</dt><dd>80.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>castelo pizzaria</dd>\n<dt>City</dt><dd>Acarau</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>78.69 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Maui Seaside Hotel</dd>\n<dt>City</dt><dd>Kahului</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>89.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>KOSAN UNGU UNSIK</dd>\n<dt>City</dt><dd>Kawalu</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>80.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ashok Hotel</dd>\n<dt>City</dt><dd>Wani</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>78.89 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>MAMA HOTAL</dd>\n<dt>City</dt><dd>Karera</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>78.3 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Montana Hotel Syariah</dd>\n<dt>City</dt><dd>Martapura</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>86.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Bheemili Court</dd>\n<dt>City</dt><dd>Bhimunipatnam</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>80.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Dora, Bubaque</dd>\n<dt>City</dt><dd>Bubaque</dd>\n<dt>Country</dt><dd>GW</dd>\n<dt>Max Temp</dt><dd>82.83 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>U Mya</dd>\n<dt>City</dt><dd>Yamethin</dd>\n<dt>Country</dt><dd>MM</dd>\n<dt>Max Temp</dt><dd>81.28 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Coconut Creek Resort</dd>\n<dt>City</dt><dd>Mormugao</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>80.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Container Inn Puerto Vallarta</dd>\n<dt>City</dt><dd>Ixtapa</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>86.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pelindung Bawah Losmen</dd>\n<dt>City</dt><dd>Kabanjahe</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>80.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Seri Simanggang Hotel</dd>\n<dt>City</dt><dd>Sri Aman</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Max Temp</dt><dd>84.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel The Royal Honours</dd>\n<dt>City</dt><dd>Mangrol</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>81.95 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Khách sạn Sài Gòn Bạc Liêu</dd>\n<dt>City</dt><dd>Bac Lieu</dd>\n<dt>Country</dt><dd>VN</dd>\n<dt>Max Temp</dt><dd>83.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tiara Labuan Hotel</dd>\n<dt>City</dt><dd>Labuan</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Max Temp</dt><dd>84.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Fortune Resort Bay Island</dd>\n<dt>City</dt><dd>Port Blair</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>84.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mantra Trilogy Cairns</dd>\n<dt>City</dt><dd>Cairns</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>88.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Collection O Hotel Quinta Antigua</dd>\n<dt>City</dt><dd>Lazaro Cardenas</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>80.92 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Muna Hotel</dd>\n<dt>City</dt><dd>Yola</dd>\n<dt>Country</dt><dd>NG</dd>\n<dt>Max Temp</dt><dd>79.9 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Narayan Avezika Comfort</dd>\n<dt>City</dt><dd>Dwarka</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>82.54 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>OYO 37764 Ghala Tourist Home</dd>\n<dt>City</dt><dd>Elur</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>78.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Royal Floridian Resort By Spinnaker Resorts</dd>\n<dt>City</dt><dd>Ormond Beach</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>78.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Kudahuvadhoo Retreat</dd>\n<dt>City</dt><dd>Kudahuvadhoo</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Max Temp</dt><dd>82.47 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Field Lilies - Trairi</dd>\n<dt>City</dt><dd>Trairi</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>79.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Taoudenni</dd>\n<dt>Country</dt><dd>ML</dd>\n<dt>Max Temp</dt><dd>84.88 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Osmani Hotel</dd>\n<dt>City</dt><dd>Hobyo</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Max Temp</dt><dd>79.45 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Vanira Lodge</dd>\n<dt>City</dt><dd>Teahupoo</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>80.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Catalina</dd>\n<dt>City</dt><dd>Rosamorada</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>80.38 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Myhousebythesea</dd>\n<dt>City</dt><dd>Palauig</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>83.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Almuñecar Hotel</dd>\n<dt>City</dt><dd>Tartagal</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Max Temp</dt><dd>82.83 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>neotel hotel kuala lumpur</dd>\n<dt>City</dt><dd>Mentakab</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Max Temp</dt><dd>85.57 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sriram residency</dd>\n<dt>City</dt><dd>Srikakulam</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>80.31 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Araouane</dd>\n<dt>Country</dt><dd>ML</dd>\n<dt>Max Temp</dt><dd>85.44 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Estación de Chagres</dd>\n<dt>City</dt><dd>Palmas Bellas</dd>\n<dt>Country</dt><dd>PA</dd>\n<dt>Max Temp</dt><dd>80.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>SanBiz Lodge</dd>\n<dt>City</dt><dd>Kirakira</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Max Temp</dt><dd>84.02 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>OYO 412 Viewfort Venue</dd>\n<dt>City</dt><dd>San Pedro</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>84.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Edd</dd>\n<dt>Country</dt><dd>ER</dd>\n<dt>Max Temp</dt><dd>83.05 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Jelly's House</dd>\n<dt>City</dt><dd>Trang</dd>\n<dt>Country</dt><dd>TH</dd>\n<dt>Max Temp</dt><dd>82.0 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Fonatur Operadora Portuaría</dd>\n<dt>City</dt><dd>Huatulco</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>80.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Grand Kecubung Hotel</dd>\n<dt>City</dt><dd>Pangkalanbuun</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>89.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Villa Orphee</dd>\n<dt>City</dt><dd>Les Cayes</dd>\n<dt>Country</dt><dd>HT</dd>\n<dt>Max Temp</dt><dd>79.65 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Osprey Beach Hotel</dd>\n<dt>City</dt><dd>Cockburn Town</dd>\n<dt>Country</dt><dd>TC</dd>\n<dt>Max Temp</dt><dd>83.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Colinas de Matasiete</dd>\n<dt>City</dt><dd>La Asuncion</dd>\n<dt>Country</dt><dd>VE</dd>\n<dt>Max Temp</dt><dd>89.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mega Hotel, Miri</dd>\n<dt>City</dt><dd>Miri</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Max Temp</dt><dd>86.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Aitape</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>84.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Welcombe Hotel</dd>\n<dt>City</dt><dd>Trincomalee</dd>\n<dt>Country</dt><dd>LK</dd>\n<dt>Max Temp</dt><dd>82.9 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Pinheiro</dd>\n<dt>City</dt><dd>Jaguaribe</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>79.79 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Fengshui Residence</dd>\n<dt>City</dt><dd>Port-Gentil</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Max Temp</dt><dd>78.28 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>CeBlue Villas & Beach Resort</dd>\n<dt>City</dt><dd>The Valley</dd>\n<dt>Country</dt><dd>AI</dd>\n<dt>Max Temp</dt><dd>84.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nuli Sapi</dd>\n<dt>City</dt><dd>Samarai</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>81.77 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Guangzhou Hotel</dd>\n<dt>City</dt><dd>Canton</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Max Temp</dt><dd>84.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Igreja da paz</dd>\n<dt>City</dt><dd>Terra Santa</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>78.01 °F</dd>\n</dl>\n']

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e2f5f2acde72> in <module>
#       1 # Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
# ----> 2 locations = hotel_df[["Lat", "Lng"]]
#       3 max_temp = hotel_df["Max Temp"]
#       4 fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#       5 heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
#
# NameError: name 'hotel_df' is not defined
