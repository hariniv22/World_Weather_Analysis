# %%
# import our dependencies
import requests
import pandas as pd
import gmaps
from citipy import citipy
import numpy as np
from config import weather_api_key
from datetime import datetime

# %%
# create 2000 random latitudes and longitudes
lats = np.random.uniform(-90, 90, size=2000)
langs = np.random.uniform(-180, 180, size=2000)
lats_langs = zip(lats,langs)
coordinates = list(lats_langs)
coordinates[0]
# Out:
# (-2.017172014322469, 108.60642635542354)

# %%
# Get the nearest city
# Create a list for holding the cities.
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
            cities.append(city)
len(cities)
# Out:
# 731

# %%
# create an empty list for weather data
city_data =[]
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
record_count = 1
set_count = 1
for i, city in enumerate(cities):
    print(i)
    # Group cities in sets of 50 for logging purposes.
    if (i % 50==0 and i >= 50):
        set_count += 1
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
     # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        city_weather = requests.get(city_url).json()
        # Parse the JSON and retrieve data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_data.append({"City": city.title(),
                      "Lat": city_lat,
                      "Lng": city_lng,
                      "Max Temp": city_max_temp,
                      "Humidity": city_humidity,
                      "Cloudiness": city_clouds,
                      "Wind Speed": city_wind,
                      "Country": city_country,
                      "Current Description": city_description,
                      "Date": city_date})
    except:
        print(f"City not found..Skipping")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# 0
# Processing Record 1 of Set 1 | manggar
# 1
# Processing Record 2 of Set 1 | busselton
# 2
# Processing Record 3 of Set 1 | punta arenas
# 3
# Processing Record 4 of Set 1 | riyadh
# 4
# Processing Record 5 of Set 1 | belushya guba
# City not found..Skipping
# 5
# Processing Record 6 of Set 1 | puerto ayora
# 6
# Processing Record 7 of Set 1 | kodiak
# 7
# Processing Record 8 of Set 1 | sentyabrskiy
# City not found..Skipping
# 8
# Processing Record 9 of Set 1 | sioux lookout
# 9
# Processing Record 10 of Set 1 | avarua
# 10
# Processing Record 11 of Set 1 | phonhong
# 11
# Processing Record 12 of Set 1 | hilo
# 12
# Processing Record 13 of Set 1 | qaanaaq
# 13
# Processing Record 14 of Set 1 | eyl
# 14
# Processing Record 15 of Set 1 | palmares do sul
# 15
# Processing Record 16 of Set 1 | jujuy
# City not found..Skipping
# 16
# Processing Record 17 of Set 1 | upernavik
# 17
# Processing Record 18 of Set 1 | chuy
# 18
# Processing Record 19 of Set 1 | lugazi
# 19
# Processing Record 20 of Set 1 | vaini
# 20
# Processing Record 21 of Set 1 | west bay
# 21
# Processing Record 22 of Set 1 | anton lizardo
# 22
# Processing Record 23 of Set 1 | alta floresta
# 23
# Processing Record 24 of Set 1 | atuona
# 24
# Processing Record 25 of Set 1 | albany
# 25
# Processing Record 26 of Set 1 | cape town
# 26
# Processing Record 27 of Set 1 | la fleche
# 27
# Processing Record 28 of Set 1 | auki
# 28
# Processing Record 29 of Set 1 | hobyo
# 29
# Processing Record 30 of Set 1 | halalo
# City not found..Skipping
# 30
# Processing Record 31 of Set 1 | bambous virieux
# 31
# Processing Record 32 of Set 1 | bluff
# 32
# Processing Record 33 of Set 1 | sarangani
# 33
# Processing Record 34 of Set 1 | lisakovsk
# 34
# Processing Record 35 of Set 1 | ihosy
# 35
# Processing Record 36 of Set 1 | baruun-urt
# 36
# Processing Record 37 of Set 1 | eirunepe
# 37
# Processing Record 38 of Set 1 | destin
# 38
# Processing Record 39 of Set 1 | honiara
# 39
# Processing Record 40 of Set 1 | ribeira grande
# 40
# Processing Record 41 of Set 1 | mataura
# 41
# Processing Record 42 of Set 1 | ancud
# 42
# Processing Record 43 of Set 1 | kavieng
# 43
# Processing Record 44 of Set 1 | hamilton
# 44
# Processing Record 45 of Set 1 | komsomolskiy
# 45
# Processing Record 46 of Set 1 | hihifo
# City not found..Skipping
# 46
# Processing Record 47 of Set 1 | barentsburg
# City not found..Skipping
# 47
# Processing Record 48 of Set 1 | shuyskoye
# 48
# Processing Record 49 of Set 1 | talcahuano
# 49
# Processing Record 50 of Set 1 | port-cartier
# 50
# Processing Record 51 of Set 2 | tuktoyaktuk
# 51
# Processing Record 52 of Set 2 | santa maria
# 52
# Processing Record 53 of Set 2 | dingle
# 53
# Processing Record 54 of Set 2 | jamestown
# 54
# Processing Record 55 of Set 2 | puertollano
# 55
# Processing Record 56 of Set 2 | merauke
# 56
# Processing Record 57 of Set 2 | kota belud
# 57
# Processing Record 58 of Set 2 | constitucion
# 58
# Processing Record 59 of Set 2 | norman wells
# 59
# Processing Record 60 of Set 2 | carbonia
# 60
# Processing Record 61 of Set 2 | tasiilaq
# 61
# Processing Record 62 of Set 2 | muscat
# 62
# Processing Record 63 of Set 2 | rikitea
# 63
# Processing Record 64 of Set 2 | dalgopol
# 64
# Processing Record 65 of Set 2 | dikson
# 65
# Processing Record 66 of Set 2 | luwuk
# 66
# Processing Record 67 of Set 2 | victoria
# 67
# Processing Record 68 of Set 2 | mount isa
# 68
# Processing Record 69 of Set 2 | flin flon
# 69
# Processing Record 70 of Set 2 | sao gabriel da cachoeira
# 70
# Processing Record 71 of Set 2 | new norfolk
# 71
# Processing Record 72 of Set 2 | hobart
# 72
# Processing Record 73 of Set 2 | kruisfontein
# 73
# Processing Record 74 of Set 2 | dullewala
# 74
# Processing Record 75 of Set 2 | umm lajj
# 75
# Processing Record 76 of Set 2 | marawi
# 76
# Processing Record 77 of Set 2 | ushuaia
# 77
# Processing Record 78 of Set 2 | bredasdorp
# 78
# Processing Record 79 of Set 2 | port alfred
# 79
# Processing Record 80 of Set 2 | muros
# 80
# Processing Record 81 of Set 2 | leningradskiy
# 81
# Processing Record 82 of Set 2 | butaritari
# 82
# Processing Record 83 of Set 2 | georgetown
# 83
# Processing Record 84 of Set 2 | kapaa
# 84
# Processing Record 85 of Set 2 | severo-kurilsk
# 85
# Processing Record 86 of Set 2 | arraial do cabo
# 86
# Processing Record 87 of Set 2 | barrow
# 87
# Processing Record 88 of Set 2 | mahebourg
# 88
# Processing Record 89 of Set 2 | clyde river
# 89
# Processing Record 90 of Set 2 | hermanus
# 90
# Processing Record 91 of Set 2 | chapais
# 91
# Processing Record 92 of Set 2 | sitka
# 92
# Processing Record 93 of Set 2 | provideniya
# 93
# Processing Record 94 of Set 2 | porto novo
# 94
# Processing Record 95 of Set 2 | ust-nera
# 95
# Processing Record 96 of Set 2 | tawkar
# City not found..Skipping
# 96
# Processing Record 97 of Set 2 | hervey bay
# 97
# Processing Record 98 of Set 2 | lompoc
# 98
# Processing Record 99 of Set 2 | ust-kuyga
# 99
# Processing Record 100 of Set 2 | yatou
# 100
# Processing Record 101 of Set 3 | bandarbeyla
# 101
# Processing Record 102 of Set 3 | mar del plata
# 102
# Processing Record 103 of Set 3 | pisco
# 103
# Processing Record 104 of Set 3 | bethel
# 104
# Processing Record 105 of Set 3 | college
# 105
# Processing Record 106 of Set 3 | ponta do sol
# 106
# Processing Record 107 of Set 3 | faya
# 107
# Processing Record 108 of Set 3 | aberdeen
# 108
# Processing Record 109 of Set 3 | scottsbluff
# 109
# Processing Record 110 of Set 3 | attawapiskat
# City not found..Skipping
# 110
# Processing Record 111 of Set 3 | avera
# 111
# Processing Record 112 of Set 3 | nikolskoye
# 112
# Processing Record 113 of Set 3 | thompson
# 113
# Processing Record 114 of Set 3 | klaksvik
# 114
# Processing Record 115 of Set 3 | amderma
# City not found..Skipping
# 115
# Processing Record 116 of Set 3 | loukhi
# 116
# Processing Record 117 of Set 3 | masumbwe
# 117
# Processing Record 118 of Set 3 | mancio lima
# 118
# Processing Record 119 of Set 3 | boca do acre
# 119
# Processing Record 120 of Set 3 | taolanaro
# City not found..Skipping
# 120
# Processing Record 121 of Set 3 | haverfordwest
# 121
# Processing Record 122 of Set 3 | marcona
# City not found..Skipping
# 122
# Processing Record 123 of Set 3 | khatanga
# 123
# Processing Record 124 of Set 3 | hasaki
# 124
# Processing Record 125 of Set 3 | rosetta
# 125
# Processing Record 126 of Set 3 | imeni poliny osipenko
# 126
# Processing Record 127 of Set 3 | pangnirtung
# 127
# Processing Record 128 of Set 3 | banjar
# 128
# Processing Record 129 of Set 3 | portland
# 129
# Processing Record 130 of Set 3 | port lincoln
# 130
# Processing Record 131 of Set 3 | hailey
# 131
# Processing Record 132 of Set 3 | nanortalik
# 132
# Processing Record 133 of Set 3 | comodoro rivadavia
# 133
# Processing Record 134 of Set 3 | tuatapere
# 134
# Processing Record 135 of Set 3 | necochea
# 135
# Processing Record 136 of Set 3 | alamos
# 136
# Processing Record 137 of Set 3 | illoqqortoormiut
# City not found..Skipping
# 137
# Processing Record 138 of Set 3 | lebu
# 138
# Processing Record 139 of Set 3 | longlac
# City not found..Skipping
# 139
# Processing Record 140 of Set 3 | tucupita
# 140
# Processing Record 141 of Set 3 | aklavik
# 141
# Processing Record 142 of Set 3 | hambantota
# 142
# Processing Record 143 of Set 3 | zhigansk
# 143
# Processing Record 144 of Set 3 | saskylakh
# 144
# Processing Record 145 of Set 3 | yanchukan
# City not found..Skipping
# 145
# Processing Record 146 of Set 3 | horn lake
# 146
# Processing Record 147 of Set 3 | vila velha
# 147
# Processing Record 148 of Set 3 | lixourion
# 148
# Processing Record 149 of Set 3 | esmeraldas
# 149
# Processing Record 150 of Set 3 | esperance
# 150
# Processing Record 151 of Set 4 | aflu
# City not found..Skipping
# 151
# Processing Record 152 of Set 4 | olafsvik
# 152
# Processing Record 153 of Set 4 | faanui
# 153
# Processing Record 154 of Set 4 | samusu
# City not found..Skipping
# 154
# Processing Record 155 of Set 4 | kamenka
# 155
# Processing Record 156 of Set 4 | hithadhoo
# 156
# Processing Record 157 of Set 4 | saint-philippe
# 157
# Processing Record 158 of Set 4 | svetlogorsk
# 158
# Processing Record 159 of Set 4 | cabo san lucas
# 159
# Processing Record 160 of Set 4 | tautira
# 160
# Processing Record 161 of Set 4 | san patricio
# 161
# Processing Record 162 of Set 4 | voh
# 162
# Processing Record 163 of Set 4 | oranjemund
# 163
# Processing Record 164 of Set 4 | ijaki
# City not found..Skipping
# 164
# Processing Record 165 of Set 4 | yellowknife
# 165
# Processing Record 166 of Set 4 | torbay
# 166
# Processing Record 167 of Set 4 | awbari
# 167
# Processing Record 168 of Set 4 | zomin
# 168
# Processing Record 169 of Set 4 | pauini
# 169
# Processing Record 170 of Set 4 | xinzhou
# 170
# Processing Record 171 of Set 4 | yumen
# 171
# Processing Record 172 of Set 4 | elat
# 172
# Processing Record 173 of Set 4 | coahuayana
# 173
# Processing Record 174 of Set 4 | taoudenni
# 174
# Processing Record 175 of Set 4 | saint-leu
# 175
# Processing Record 176 of Set 4 | palabuhanratu
# City not found..Skipping
# 176
# Processing Record 177 of Set 4 | lasa
# 177
# Processing Record 178 of Set 4 | yaan
# 178
# Processing Record 179 of Set 4 | carnarvon
# 179
# Processing Record 180 of Set 4 | hofn
# 180
# Processing Record 181 of Set 4 | safaga
# 181
# Processing Record 182 of Set 4 | mineros
# 182
# Processing Record 183 of Set 4 | kitgum
# 183
# Processing Record 184 of Set 4 | sahrak
# City not found..Skipping
# 184
# Processing Record 185 of Set 4 | anadyr
# 185
# Processing Record 186 of Set 4 | lagoa
# 186
# Processing Record 187 of Set 4 | tahoua
# 187
# Processing Record 188 of Set 4 | naftah
# City not found..Skipping
# 188
# Processing Record 189 of Set 4 | nassjo
# 189
# Processing Record 190 of Set 4 | llandrindod wells
# 190
# Processing Record 191 of Set 4 | saleaula
# City not found..Skipping
# 191
# Processing Record 192 of Set 4 | bol
# 192
# Processing Record 193 of Set 4 | dalbandin
# 193
# Processing Record 194 of Set 4 | kahului
# 194
# Processing Record 195 of Set 4 | meulaboh
# 195
# Processing Record 196 of Set 4 | saint-pierre
# 196
# Processing Record 197 of Set 4 | valdemarpils
# 197
# Processing Record 198 of Set 4 | grand gaube
# 198
# Processing Record 199 of Set 4 | kolokani
# 199
# Processing Record 200 of Set 4 | east london
# 200
# Processing Record 201 of Set 5 | nantucket
# 201
# Processing Record 202 of Set 5 | shelburne
# 202
# Processing Record 203 of Set 5 | alofi
# 203
# Processing Record 204 of Set 5 | williston
# 204
# Processing Record 205 of Set 5 | louisbourg
# City not found..Skipping
# 205
# Processing Record 206 of Set 5 | tura
# 206
# Processing Record 207 of Set 5 | caravelas
# 207
# Processing Record 208 of Set 5 | san cristobal
# 208
# Processing Record 209 of Set 5 | menongue
# 209
# Processing Record 210 of Set 5 | castro
# 210
# Processing Record 211 of Set 5 | sechura
# 211
# Processing Record 212 of Set 5 | alice springs
# 212
# Processing Record 213 of Set 5 | saldanha
# 213
# Processing Record 214 of Set 5 | sao filipe
# 214
# Processing Record 215 of Set 5 | kaitangata
# 215
# Processing Record 216 of Set 5 | palm coast
# 216
# Processing Record 217 of Set 5 | hashimoto
# 217
# Processing Record 218 of Set 5 | ucluelet
# 218
# Processing Record 219 of Set 5 | uthal
# 219
# Processing Record 220 of Set 5 | bowen
# 220
# Processing Record 221 of Set 5 | termoli
# 221
# Processing Record 222 of Set 5 | toliary
# City not found..Skipping
# 222
# Processing Record 223 of Set 5 | sola
# 223
# Processing Record 224 of Set 5 | lanzhou
# 224
# Processing Record 225 of Set 5 | pevek
# 225
# Processing Record 226 of Set 5 | qasigiannguit
# 226
# Processing Record 227 of Set 5 | sibu
# 227
# Processing Record 228 of Set 5 | xinyang
# 228
# Processing Record 229 of Set 5 | sorong
# 229
# Processing Record 230 of Set 5 | kutum
# 230
# Processing Record 231 of Set 5 | balkanabat
# 231
# Processing Record 232 of Set 5 | haines junction
# 232
# Processing Record 233 of Set 5 | okandja
# City not found..Skipping
# 233
# Processing Record 234 of Set 5 | doha
# 234
# Processing Record 235 of Set 5 | paamiut
# 235
# Processing Record 236 of Set 5 | grand river south east
# City not found..Skipping
# 236
# Processing Record 237 of Set 5 | saint-joseph
# 237
# Processing Record 238 of Set 5 | jinchengjiang
# City not found..Skipping
# 238
# Processing Record 239 of Set 5 | lavrentiya
# 239
# Processing Record 240 of Set 5 | codrington
# 240
# Processing Record 241 of Set 5 | bolshoy uluy
# City not found..Skipping
# 241
# Processing Record 242 of Set 5 | nazilli
# 242
# Processing Record 243 of Set 5 | roald
# 243
# Processing Record 244 of Set 5 | jorochito
# 244
# Processing Record 245 of Set 5 | kasempa
# 245
# Processing Record 246 of Set 5 | terrace
# 246
# Processing Record 247 of Set 5 | kendari
# 247
# Processing Record 248 of Set 5 | sarab
# 248
# Processing Record 249 of Set 5 | dzhusaly
# City not found..Skipping
# 249
# Processing Record 250 of Set 5 | kalmunai
# 250
# Processing Record 251 of Set 6 | skibbereen
# 251
# Processing Record 252 of Set 6 | rungata
# City not found..Skipping
# 252
# Processing Record 253 of Set 6 | mys shmidta
# City not found..Skipping
# 253
# Processing Record 254 of Set 6 | sistranda
# 254
# Processing Record 255 of Set 6 | vaxjo
# 255
# Processing Record 256 of Set 6 | umzimvubu
# City not found..Skipping
# 256
# Processing Record 257 of Set 6 | iwanai
# 257
# Processing Record 258 of Set 6 | ko samui
# 258
# Processing Record 259 of Set 6 | yuanping
# 259
# Processing Record 260 of Set 6 | celestun
# 260
# Processing Record 261 of Set 6 | segou
# 261
# Processing Record 262 of Set 6 | namibe
# 262
# Processing Record 263 of Set 6 | perth
# 263
# Processing Record 264 of Set 6 | leshukonskoye
# 264
# Processing Record 265 of Set 6 | luderitz
# 265
# Processing Record 266 of Set 6 | shingu
# 266
# Processing Record 267 of Set 6 | brae
# 267
# Processing Record 268 of Set 6 | trincomalee
# 268
# Processing Record 269 of Set 6 | rassvet
# 269
# Processing Record 270 of Set 6 | korhogo
# 270
# Processing Record 271 of Set 6 | ust-ishim
# 271
# Processing Record 272 of Set 6 | beloha
# 272
# Processing Record 273 of Set 6 | broken hill
# 273
# Processing Record 274 of Set 6 | sharan
# 274
# Processing Record 275 of Set 6 | saint-augustin
# 275
# Processing Record 276 of Set 6 | sisimiut
# 276
# Processing Record 277 of Set 6 | tahe
# 277
# Processing Record 278 of Set 6 | peniche
# 278
# Processing Record 279 of Set 6 | pandan
# 279
# Processing Record 280 of Set 6 | adrar
# 280
# Processing Record 281 of Set 6 | richards bay
# 281
# Processing Record 282 of Set 6 | tsihombe
# City not found..Skipping
# 282
# Processing Record 283 of Set 6 | bolungarvik
# City not found..Skipping
# 283
# Processing Record 284 of Set 6 | saint combs
# City not found..Skipping
# 284
# Processing Record 285 of Set 6 | nome
# 285
# Processing Record 286 of Set 6 | pombas
# 286
# Processing Record 287 of Set 6 | matagami
# 287
# Processing Record 288 of Set 6 | champerico
# 288
# Processing Record 289 of Set 6 | kpandu
# 289
# Processing Record 290 of Set 6 | fairbanks
# 290
# Processing Record 291 of Set 6 | wajir
# 291
# Processing Record 292 of Set 6 | chernyshevskiy
# 292
# Processing Record 293 of Set 6 | los llanos de aridane
# 293
# Processing Record 294 of Set 6 | quatre cocos
# 294
# Processing Record 295 of Set 6 | cherskiy
# 295
# Processing Record 296 of Set 6 | ormara
# 296
# Processing Record 297 of Set 6 | plymouth
# 297
# Processing Record 298 of Set 6 | husavik
# 298
# Processing Record 299 of Set 6 | chokurdakh
# 299
# Processing Record 300 of Set 6 | ixtapa
# 300
# Processing Record 301 of Set 7 | fortuna
# 301
# Processing Record 302 of Set 7 | karakendzha
# City not found..Skipping
# 302
# Processing Record 303 of Set 7 | bonavista
# 303
# Processing Record 304 of Set 7 | san juan de colon
# 304
# Processing Record 305 of Set 7 | turukhansk
# 305
# Processing Record 306 of Set 7 | papetoai
# 306
# Processing Record 307 of Set 7 | burica
# City not found..Skipping
# 307
# Processing Record 308 of Set 7 | tiksi
# 308
# Processing Record 309 of Set 7 | mitsamiouli
# 309
# Processing Record 310 of Set 7 | port elizabeth
# 310
# Processing Record 311 of Set 7 | hvammstangi
# City not found..Skipping
# 311
# Processing Record 312 of Set 7 | ozinki
# 312
# Processing Record 313 of Set 7 | jasper
# 313
# Processing Record 314 of Set 7 | shyroke
# 314
# Processing Record 315 of Set 7 | dudinka
# 315
# Processing Record 316 of Set 7 | half moon bay
# 316
# Processing Record 317 of Set 7 | aubenas
# 317
# Processing Record 318 of Set 7 | guanica
# 318
# Processing Record 319 of Set 7 | aswan
# 319
# Processing Record 320 of Set 7 | ahipara
# 320
# Processing Record 321 of Set 7 | mutsamudu
# City not found..Skipping
# 321
# Processing Record 322 of Set 7 | yerbogachen
# 322
# Processing Record 323 of Set 7 | lensk
# 323
# Processing Record 324 of Set 7 | abha
# 324
# Processing Record 325 of Set 7 | mocambique
# City not found..Skipping
# 325
# Processing Record 326 of Set 7 | kropotkin
# 326
# Processing Record 327 of Set 7 | chardara
# 327
# Processing Record 328 of Set 7 | the pas
# 328
# Processing Record 329 of Set 7 | muroto
# 329
# Processing Record 330 of Set 7 | naze
# 330
# Processing Record 331 of Set 7 | havoysund
# 331
# Processing Record 332 of Set 7 | atambua
# 332
# Processing Record 333 of Set 7 | lac-megantic
# 333
# Processing Record 334 of Set 7 | olavarria
# 334
# Processing Record 335 of Set 7 | katsuura
# 335
# Processing Record 336 of Set 7 | saint anthony
# 336
# Processing Record 337 of Set 7 | geraldton
# 337
# Processing Record 338 of Set 7 | diamantina
# 338
# Processing Record 339 of Set 7 | boyolangu
# 339
# Processing Record 340 of Set 7 | egvekinot
# 340
# Processing Record 341 of Set 7 | laguna
# 341
# Processing Record 342 of Set 7 | sidhi
# 342
# Processing Record 343 of Set 7 | binga
# 343
# Processing Record 344 of Set 7 | margate
# 344
# Processing Record 345 of Set 7 | vanavara
# 345
# Processing Record 346 of Set 7 | rognan
# 346
# Processing Record 347 of Set 7 | mikhaylovka
# 347
# Processing Record 348 of Set 7 | jalu
# 348
# Processing Record 349 of Set 7 | sulangan
# 349
# Processing Record 350 of Set 7 | nizhnevartovsk
# 350
# Processing Record 351 of Set 8 | ilhabela
# 351
# Processing Record 352 of Set 8 | chastyye
# 352
# Processing Record 353 of Set 8 | ossora
# 353
# Processing Record 354 of Set 8 | saint stephen
# 354
# Processing Record 355 of Set 8 | coihaique
# 355
# Processing Record 356 of Set 8 | magadan
# 356
# Processing Record 357 of Set 8 | emerald
# 357
# Processing Record 358 of Set 8 | rawah
# 358
# Processing Record 359 of Set 8 | lolua
# City not found..Skipping
# 359
# Processing Record 360 of Set 8 | dicabisagan
# 360
# Processing Record 361 of Set 8 | dimitrovgrad
# 361
# Processing Record 362 of Set 8 | villarrobledo
# 362
# Processing Record 363 of Set 8 | mauswagon
# City not found..Skipping
# 363
# Processing Record 364 of Set 8 | pathein
# 364
# Processing Record 365 of Set 8 | tursunzoda
# 365
# Processing Record 366 of Set 8 | porbandar
# 366
# Processing Record 367 of Set 8 | mergui
# City not found..Skipping
# 367
# Processing Record 368 of Set 8 | touros
# 368
# Processing Record 369 of Set 8 | lubao
# 369
# Processing Record 370 of Set 8 | cockburn town
# 370
# Processing Record 371 of Set 8 | visegrad
# 371
# Processing Record 372 of Set 8 | tucuman
# 372
# Processing Record 373 of Set 8 | uige
# 373
# Processing Record 374 of Set 8 | viransehir
# 374
# Processing Record 375 of Set 8 | angoche
# 375
# Processing Record 376 of Set 8 | kunnamangalam
# 376
# Processing Record 377 of Set 8 | darab
# 377
# Processing Record 378 of Set 8 | nuuk
# 378
# Processing Record 379 of Set 8 | tiarei
# 379
# Processing Record 380 of Set 8 | ternate
# 380
# Processing Record 381 of Set 8 | lahat
# 381
# Processing Record 382 of Set 8 | talnakh
# 382
# Processing Record 383 of Set 8 | alexandroupoli
# 383
# Processing Record 384 of Set 8 | etchoropo
# 384
# Processing Record 385 of Set 8 | pacific grove
# 385
# Processing Record 386 of Set 8 | cessnock
# 386
# Processing Record 387 of Set 8 | khargupur
# 387
# Processing Record 388 of Set 8 | helong
# 388
# Processing Record 389 of Set 8 | kushima
# 389
# Processing Record 390 of Set 8 | santa isabel do rio negro
# 390
# Processing Record 391 of Set 8 | carbonear
# 391
# Processing Record 392 of Set 8 | gemena
# 392
# Processing Record 393 of Set 8 | arinos
# 393
# Processing Record 394 of Set 8 | teya
# 394
# Processing Record 395 of Set 8 | ibresi
# 395
# Processing Record 396 of Set 8 | el dorado
# 396
# Processing Record 397 of Set 8 | boa vista
# 397
# Processing Record 398 of Set 8 | fare
# 398
# Processing Record 399 of Set 8 | beira
# 399
# Processing Record 400 of Set 8 | ruatoria
# City not found..Skipping
# 400
# Processing Record 401 of Set 9 | banda aceh
# 401
# Processing Record 402 of Set 9 | plettenberg bay
# 402
# Processing Record 403 of Set 9 | pochutla
# 403
# Processing Record 404 of Set 9 | zaysan
# 404
# Processing Record 405 of Set 9 | silistra
# 405
# Processing Record 406 of Set 9 | rocha
# 406
# Processing Record 407 of Set 9 | kilifi
# 407
# Processing Record 408 of Set 9 | solnechnyy
# 408
# Processing Record 409 of Set 9 | dzhebariki-khaya
# 409
# Processing Record 410 of Set 9 | nikolayevka
# 410
# Processing Record 411 of Set 9 | ha tinh
# 411
# Processing Record 412 of Set 9 | barra patuca
# 412
# Processing Record 413 of Set 9 | yarmouth
# 413
# Processing Record 414 of Set 9 | waingapu
# 414
# Processing Record 415 of Set 9 | tubruq
# City not found..Skipping
# 415
# Processing Record 416 of Set 9 | belyy yar
# 416
# Processing Record 417 of Set 9 | najran
# 417
# Processing Record 418 of Set 9 | araouane
# 418
# Processing Record 419 of Set 9 | mamallapuram
# 419
# Processing Record 420 of Set 9 | linchuan
# City not found..Skipping
# 420
# Processing Record 421 of Set 9 | penzance
# 421
# Processing Record 422 of Set 9 | ouango
# 422
# Processing Record 423 of Set 9 | beroroha
# 423
# Processing Record 424 of Set 9 | sao joao da barra
# 424
# Processing Record 425 of Set 9 | dunmore town
# 425
# Processing Record 426 of Set 9 | saint george
# 426
# Processing Record 427 of Set 9 | pangody
# 427
# Processing Record 428 of Set 9 | asau
# 428
# Processing Record 429 of Set 9 | klyuchi
# 429
# Processing Record 430 of Set 9 | srivardhan
# 430
# Processing Record 431 of Set 9 | cayenne
# 431
# Processing Record 432 of Set 9 | varkkallai
# 432
# Processing Record 433 of Set 9 | lephepe
# City not found..Skipping
# 433
# Processing Record 434 of Set 9 | imbituba
# 434
# Processing Record 435 of Set 9 | vao
# 435
# Processing Record 436 of Set 9 | port hardy
# 436
# Processing Record 437 of Set 9 | alta
# 437
# Processing Record 438 of Set 9 | jinxiang
# 438
# Processing Record 439 of Set 9 | tabou
# 439
# Processing Record 440 of Set 9 | norton
# 440
# Processing Record 441 of Set 9 | stornoway
# 441
# Processing Record 442 of Set 9 | kulhudhuffushi
# 442
# Processing Record 443 of Set 9 | christchurch
# 443
# Processing Record 444 of Set 9 | athens
# 444
# Processing Record 445 of Set 9 | launceston
# 445
# Processing Record 446 of Set 9 | gushikawa
# 446
# Processing Record 447 of Set 9 | cardenas
# 447
# Processing Record 448 of Set 9 | bengkulu
# 448
# Processing Record 449 of Set 9 | lorengau
# 449
# Processing Record 450 of Set 9 | sal rei
# 450
# Processing Record 451 of Set 10 | achisay
# City not found..Skipping
# 451
# Processing Record 452 of Set 10 | itarema
# 452
# Processing Record 453 of Set 10 | barawe
# City not found..Skipping
# 453
# Processing Record 454 of Set 10 | bargal
# City not found..Skipping
# 454
# Processing Record 455 of Set 10 | hinton
# 455
# Processing Record 456 of Set 10 | itoman
# 456
# Processing Record 457 of Set 10 | worthington
# 457
# Processing Record 458 of Set 10 | narsaq
# 458
# Processing Record 459 of Set 10 | airai
# 459
# Processing Record 460 of Set 10 | malwan
# City not found..Skipping
# 460
# Processing Record 461 of Set 10 | bukama
# 461
# Processing Record 462 of Set 10 | yeppoon
# 462
# Processing Record 463 of Set 10 | mahon
# 463
# Processing Record 464 of Set 10 | kungurtug
# 464
# Processing Record 465 of Set 10 | buqayq
# City not found..Skipping
# 465
# Processing Record 466 of Set 10 | paldiski
# 466
# Processing Record 467 of Set 10 | inhambane
# 467
# Processing Record 468 of Set 10 | dawlatabad
# 468
# Processing Record 469 of Set 10 | temaraia
# City not found..Skipping
# 469
# Processing Record 470 of Set 10 | tchollire
# 470
# Processing Record 471 of Set 10 | zyryanka
# 471
# Processing Record 472 of Set 10 | la ligua
# 472
# Processing Record 473 of Set 10 | santa margherita ligure
# 473
# Processing Record 474 of Set 10 | carovigno
# 474
# Processing Record 475 of Set 10 | viedma
# 475
# Processing Record 476 of Set 10 | coeneo
# 476
# Processing Record 477 of Set 10 | cidreira
# 477
# Processing Record 478 of Set 10 | bandundu
# 478
# Processing Record 479 of Set 10 | kuusamo
# 479
# Processing Record 480 of Set 10 | colares
# 480
# Processing Record 481 of Set 10 | monteagudo
# 481
# Processing Record 482 of Set 10 | agva
# City not found..Skipping
# 482
# Processing Record 483 of Set 10 | hammerfest
# 483
# Processing Record 484 of Set 10 | monrovia
# 484
# Processing Record 485 of Set 10 | ampanihy
# 485
# Processing Record 486 of Set 10 | san quintin
# 486
# Processing Record 487 of Set 10 | puerto escondido
# 487
# Processing Record 488 of Set 10 | derazhnya
# 488
# Processing Record 489 of Set 10 | yulara
# 489
# Processing Record 490 of Set 10 | mariental
# 490
# Processing Record 491 of Set 10 | acapulco
# 491
# Processing Record 492 of Set 10 | buariki
# City not found..Skipping
# 492
# Processing Record 493 of Set 10 | redlands
# 493
# Processing Record 494 of Set 10 | la cruz
# 494
# Processing Record 495 of Set 10 | verdalsora
# City not found..Skipping
# 495
# Processing Record 496 of Set 10 | coihueco
# 496
# Processing Record 497 of Set 10 | port blair
# 497
# Processing Record 498 of Set 10 | hirara
# 498
# Processing Record 499 of Set 10 | sabang
# 499
# Processing Record 500 of Set 10 | atikokan
# 500
# Processing Record 501 of Set 11 | korla
# 501
# Processing Record 502 of Set 11 | dunedin
# 502
# Processing Record 503 of Set 11 | shimoda
# 503
# Processing Record 504 of Set 11 | virginia beach
# 504
# Processing Record 505 of Set 11 | bilibino
# 505
# Processing Record 506 of Set 11 | timbiqui
# 506
# Processing Record 507 of Set 11 | estacion coahuila
# 507
# Processing Record 508 of Set 11 | san lorenzo
# 508
# Processing Record 509 of Set 11 | mahibadhoo
# 509
# Processing Record 510 of Set 11 | kaili
# 510
# Processing Record 511 of Set 11 | san carlos de bariloche
# 511
# Processing Record 512 of Set 11 | vestmannaeyjar
# 512
# Processing Record 513 of Set 11 | poya
# 513
# Processing Record 514 of Set 11 | nicoya
# 514
# Processing Record 515 of Set 11 | kamina
# 515
# Processing Record 516 of Set 11 | weligama
# 516
# Processing Record 517 of Set 11 | karasburg
# 517
# Processing Record 518 of Set 11 | ambalavao
# 518
# Processing Record 519 of Set 11 | pringsewu
# 519
# Processing Record 520 of Set 11 | karpathos
# 520
# Processing Record 521 of Set 11 | abbotsford
# 521
# Processing Record 522 of Set 11 | lefka
# 522
# Processing Record 523 of Set 11 | bac lieu
# 523
# Processing Record 524 of Set 11 | nola
# 524
# Processing Record 525 of Set 11 | puri
# 525
# Processing Record 526 of Set 11 | waipawa
# 526
# Processing Record 527 of Set 11 | jardim
# 527
# Processing Record 528 of Set 11 | villa carlos paz
# 528
# Processing Record 529 of Set 11 | kudahuvadhoo
# 529
# Processing Record 530 of Set 11 | niamey
# 530
# Processing Record 531 of Set 11 | conceicao do araguaia
# 531
# Processing Record 532 of Set 11 | utiroa
# City not found..Skipping
# 532
# Processing Record 533 of Set 11 | soe
# 533
# Processing Record 534 of Set 11 | sri aman
# 534
# Processing Record 535 of Set 11 | melita
# 535
# Processing Record 536 of Set 11 | bam
# 536
# Processing Record 537 of Set 11 | isangel
# 537
# Processing Record 538 of Set 11 | sarkand
# 538
# Processing Record 539 of Set 11 | saiha
# 539
# Processing Record 540 of Set 11 | tilichiki
# 540
# Processing Record 541 of Set 11 | khandyga
# 541
# Processing Record 542 of Set 11 | nizhneyansk
# City not found..Skipping
# 542
# Processing Record 543 of Set 11 | pulaski
# 543
# Processing Record 544 of Set 11 | ziro
# 544
# Processing Record 545 of Set 11 | yanan
# City not found..Skipping
# 545
# Processing Record 546 of Set 11 | arona
# 546
# Processing Record 547 of Set 11 | haibowan
# City not found..Skipping
# 547
# Processing Record 548 of Set 11 | mezen
# 548
# Processing Record 549 of Set 11 | grootfontein
# 549
# Processing Record 550 of Set 11 | chingirlau
# 550
# Processing Record 551 of Set 12 | roma
# 551
# Processing Record 552 of Set 12 | calabozo
# 552
# Processing Record 553 of Set 12 | sao felix do xingu
# 553
# Processing Record 554 of Set 12 | sikandarpur
# 554
# Processing Record 555 of Set 12 | sydney
# 555
# Processing Record 556 of Set 12 | san lawrenz
# 556
# Processing Record 557 of Set 12 | paracatu
# 557
# Processing Record 558 of Set 12 | kawana waters
# City not found..Skipping
# 558
# Processing Record 559 of Set 12 | surt
# 559
# Processing Record 560 of Set 12 | brandon
# 560
# Processing Record 561 of Set 12 | chegutu
# 561
# Processing Record 562 of Set 12 | mount gambier
# 562
# Processing Record 563 of Set 12 | mbini
# 563
# Processing Record 564 of Set 12 | treinta y tres
# 564
# Processing Record 565 of Set 12 | townsville
# 565
# Processing Record 566 of Set 12 | kurilsk
# 566
# Processing Record 567 of Set 12 | kawalu
# 567
# Processing Record 568 of Set 12 | coralville
# 568
# Processing Record 569 of Set 12 | tabiauea
# City not found..Skipping
# 569
# Processing Record 570 of Set 12 | darnah
# 570
# Processing Record 571 of Set 12 | paragominas
# 571
# Processing Record 572 of Set 12 | iqaluit
# 572
# Processing Record 573 of Set 12 | xining
# 573
# Processing Record 574 of Set 12 | livny
# 574
# Processing Record 575 of Set 12 | batemans bay
# 575
# Processing Record 576 of Set 12 | kununurra
# 576
# Processing Record 577 of Set 12 | balkhash
# 577
# Processing Record 578 of Set 12 | north shore
# 578
# Processing Record 579 of Set 12 | nouadhibou
# 579
# Processing Record 580 of Set 12 | perrenjas
# City not found..Skipping
# 580
# Processing Record 581 of Set 12 | vaitupu
# City not found..Skipping
# 581
# Processing Record 582 of Set 12 | conceicao do almeida
# 582
# Processing Record 583 of Set 12 | ambon
# 583
# Processing Record 584 of Set 12 | leh
# 584
# Processing Record 585 of Set 12 | tarabuco
# 585
# Processing Record 586 of Set 12 | suruc
# 586
# Processing Record 587 of Set 12 | uni
# 587
# Processing Record 588 of Set 12 | verkhnevilyuysk
# 588
# Processing Record 589 of Set 12 | luanshya
# 589
# Processing Record 590 of Set 12 | mogadishu
# 590
# Processing Record 591 of Set 12 | suarez
# 591
# Processing Record 592 of Set 12 | salta
# 592
# Processing Record 593 of Set 12 | dukat
# 593
# Processing Record 594 of Set 12 | shenjiamen
# 594
# Processing Record 595 of Set 12 | qui nhon
# 595
# Processing Record 596 of Set 12 | yingkou
# 596
# Processing Record 597 of Set 12 | fort wayne
# 597
# Processing Record 598 of Set 12 | wenling
# 598
# Processing Record 599 of Set 12 | wankaner
# 599
# Processing Record 600 of Set 12 | yershichi
# 600
# Processing Record 601 of Set 13 | meyungs
# City not found..Skipping
# 601
# Processing Record 602 of Set 13 | novoalekseyevskaya
# 602
# Processing Record 603 of Set 13 | vila franca do campo
# 603
# Processing Record 604 of Set 13 | bridlington
# 604
# Processing Record 605 of Set 13 | shache
# 605
# Processing Record 606 of Set 13 | farafangana
# 606
# Processing Record 607 of Set 13 | marana
# 607
# Processing Record 608 of Set 13 | acarau
# 608
# Processing Record 609 of Set 13 | otukpo
# 609
# Processing Record 610 of Set 13 | yar-sale
# 610
# Processing Record 611 of Set 13 | port-gentil
# 611
# Processing Record 612 of Set 13 | sobolevo
# 612
# Processing Record 613 of Set 13 | shahrud
# 613
# Processing Record 614 of Set 13 | mocuba
# 614
# Processing Record 615 of Set 13 | westport
# 615
# Processing Record 616 of Set 13 | wabag
# 616
# Processing Record 617 of Set 13 | aykhal
# 617
# Processing Record 618 of Set 13 | chanthaburi
# 618
# Processing Record 619 of Set 13 | chore
# City not found..Skipping
# 619
# Processing Record 620 of Set 13 | casa grande
# 620
# Processing Record 621 of Set 13 | walker mill
# 621
# Processing Record 622 of Set 13 | gharghoda
# 622
# Processing Record 623 of Set 13 | sarany
# 623
# Processing Record 624 of Set 13 | berbera
# 624
# Processing Record 625 of Set 13 | chirongui
# 625
# Processing Record 626 of Set 13 | irece
# 626
# Processing Record 627 of Set 13 | ambilobe
# 627
# Processing Record 628 of Set 13 | taitung
# 628
# Processing Record 629 of Set 13 | sembe
# 629
# Processing Record 630 of Set 13 | tsiroanomandidy
# 630
# Processing Record 631 of Set 13 | machinga
# 631
# Processing Record 632 of Set 13 | moranbah
# 632
# Processing Record 633 of Set 13 | tigil
# 633
# Processing Record 634 of Set 13 | moron
# 634
# Processing Record 635 of Set 13 | kiunga
# 635
# Processing Record 636 of Set 13 | hegang
# 636
# Processing Record 637 of Set 13 | novaya ladoga
# 637
# Processing Record 638 of Set 13 | den helder
# 638
# Processing Record 639 of Set 13 | cap malheureux
# 639
# Processing Record 640 of Set 13 | longyearbyen
# 640
# Processing Record 641 of Set 13 | maragogi
# 641
# Processing Record 642 of Set 13 | aasiaat
# 642
# Processing Record 643 of Set 13 | sinnamary
# 643
# Processing Record 644 of Set 13 | kambove
# 644
# Processing Record 645 of Set 13 | saint-francois
# 645
# Processing Record 646 of Set 13 | ahumada
# City not found..Skipping
# 646
# Processing Record 647 of Set 13 | jiddah
# City not found..Skipping
# 647
# Processing Record 648 of Set 13 | panama city
# 648
# Processing Record 649 of Set 13 | beirut
# 649
# Processing Record 650 of Set 13 | hokitika
# 650
# Processing Record 651 of Set 14 | nabire
# 651
# Processing Record 652 of Set 14 | ozgon
# City not found..Skipping
# 652
# Processing Record 653 of Set 14 | sangar
# 653
# Processing Record 654 of Set 14 | veraval
# 654
# Processing Record 655 of Set 14 | opuwo
# 655
# Processing Record 656 of Set 14 | jizan
# 656
# Processing Record 657 of Set 14 | dromolaxia
# 657
# Processing Record 658 of Set 14 | santa fe do sul
# 658
# Processing Record 659 of Set 14 | tezu
# 659
# Processing Record 660 of Set 14 | elizabeth city
# 660
# Processing Record 661 of Set 14 | kirakira
# 661
# Processing Record 662 of Set 14 | yingcheng
# 662
# Processing Record 663 of Set 14 | sambava
# 663
# Processing Record 664 of Set 14 | toktogul
# 664
# Processing Record 665 of Set 14 | sturgis
# 665
# Processing Record 666 of Set 14 | souillac
# 666
# Processing Record 667 of Set 14 | tucuma
# 667
# Processing Record 668 of Set 14 | vostok
# 668
# Processing Record 669 of Set 14 | aloleng
# 669
# Processing Record 670 of Set 14 | garowe
# 670
# Processing Record 671 of Set 14 | ketchikan
# 671
# Processing Record 672 of Set 14 | grajau
# 672
# Processing Record 673 of Set 14 | ponta delgada
# 673
# Processing Record 674 of Set 14 | babylon
# 674
# Processing Record 675 of Set 14 | kristiansund
# 675
# Processing Record 676 of Set 14 | samarai
# 676
# Processing Record 677 of Set 14 | waddan
# 677
# Processing Record 678 of Set 14 | alto piquiri
# 678
# Processing Record 679 of Set 14 | liaozhong
# 679
# Processing Record 680 of Set 14 | kikwit
# 680
# Processing Record 681 of Set 14 | dire
# 681
# Processing Record 682 of Set 14 | landeck
# 682
# Processing Record 683 of Set 14 | klagenfurt
# 683
# Processing Record 684 of Set 14 | teknaf
# 684
# Processing Record 685 of Set 14 | chegdomyn
# 685
# Processing Record 686 of Set 14 | stara zagora
# 686
# Processing Record 687 of Set 14 | oriximina
# 687
# Processing Record 688 of Set 14 | xique-xique
# 688
# Processing Record 689 of Set 14 | takaka
# 689
# Processing Record 690 of Set 14 | lima
# 690
# Processing Record 691 of Set 14 | padang
# 691
# Processing Record 692 of Set 14 | staryy nadym
# 692
# Processing Record 693 of Set 14 | novyy urengoy
# 693
# Processing Record 694 of Set 14 | ust-omchug
# 694
# Processing Record 695 of Set 14 | novo aripuana
# 695
# Processing Record 696 of Set 14 | venezuela
# 696
# Processing Record 697 of Set 14 | batagay-alyta
# 697
# Processing Record 698 of Set 14 | looc
# 698
# Processing Record 699 of Set 14 | chiredzi
# 699
# Processing Record 700 of Set 14 | te anau
# 700
# Processing Record 701 of Set 15 | bumba
# 701
# Processing Record 702 of Set 15 | sorvag
# City not found..Skipping
# 702
# Processing Record 703 of Set 15 | chalus
# 703
# Processing Record 704 of Set 15 | san martin
# 704
# Processing Record 705 of Set 15 | bairiki
# 705
# Processing Record 706 of Set 15 | san ramon
# 706
# Processing Record 707 of Set 15 | mizan teferi
# 707
# Processing Record 708 of Set 15 | karpogory
# 708
# Processing Record 709 of Set 15 | concarneau
# 709
# Processing Record 710 of Set 15 | santa cruz cabralia
# 710
# Processing Record 711 of Set 15 | oudtshoorn
# 711
# Processing Record 712 of Set 15 | raga
# 712
# Processing Record 713 of Set 15 | anchorage
# 713
# Processing Record 714 of Set 15 | savinka
# 714
# Processing Record 715 of Set 15 | kamenskoye
# City not found..Skipping
# 715
# Processing Record 716 of Set 15 | zlobin
# 716
# Processing Record 717 of Set 15 | mana
# 717
# Processing Record 718 of Set 15 | mecca
# 718
# Processing Record 719 of Set 15 | annamalainagar
# 719
# Processing Record 720 of Set 15 | bose
# 720
# Processing Record 721 of Set 15 | kaeo
# 721
# Processing Record 722 of Set 15 | guilin
# 722
# Processing Record 723 of Set 15 | san rafael
# 723
# Processing Record 724 of Set 15 | neiafu
# 724
# Processing Record 725 of Set 15 | kukushtan
# 725
# Processing Record 726 of Set 15 | yingzhong
# City not found..Skipping
# 726
# Processing Record 727 of Set 15 | sept-iles
# 727
# Processing Record 728 of Set 15 | bodden town
# 728
# Processing Record 729 of Set 15 | jobabo
# 729
# Processing Record 730 of Set 15 | fort smith
# 730
# Processing Record 731 of Set 15 | urumqi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 660

# %%
# Add data to dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Manggar  -2.88  108.27     80.94        81         100        6.31
# 1       Busselton -33.65  115.33     55.00        65           0        0.43
# 2    Punta Arenas -53.15  -70.92     44.60        81          40        8.05
# 3          Riyadh  24.69   46.72     69.80        35           0        6.17
# 4    Puerto Ayora  -0.74  -90.35     78.80        69          40       20.80
# ..            ...    ...     ...       ...       ...         ...         ...
# 655     Sept-Iles  50.20  -66.38     37.00        43          75       11.41
# 656   Bodden Town  19.28  -81.25     80.60        88          75       16.11
# 657        Jobabo  20.97  -76.30     87.80        62          75       12.75
# 658    Fort Smith  35.39  -94.40     55.99        62          90        6.93
# 659        Urumqi  43.80   87.60     37.40        64           0        2.24
#
#     Country Current Description                 Date
# 0        ID       moderate rain  2020-10-25 19:52:05
# 1        AU           clear sky  2020-10-25 19:52:05
# 2        CL    scattered clouds  2020-10-25 19:49:16
# 3        SA           clear sky  2020-10-25 19:51:42
# 4        EC    scattered clouds  2020-10-25 19:47:52
# ..      ...                 ...                  ...
# 655      CA       broken clouds  2020-10-25 19:54:35
# 656      KY       broken clouds  2020-10-25 19:54:36
# 657      CU       broken clouds  2020-10-25 19:54:36
# 658      US     overcast clouds  2020-10-25 19:52:30
# 659      CN           clear sky  2020-10-25 19:54:36
#
# [660 rows x 10 columns]

# %%
# Reorder the columns
new_columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_columns]
city_data_df.head(10)
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Manggar      ID  -2.88  108.27     80.94        81         100
# 1      Busselton      AU -33.65  115.33     55.00        65           0
# 2   Punta Arenas      CL -53.15  -70.92     44.60        81          40
# 3         Riyadh      SA  24.69   46.72     69.80        35           0
# 4   Puerto Ayora      EC  -0.74  -90.35     78.80        69          40
# 5         Kodiak      US  57.79 -152.41     48.20        87          90
# 6  Sioux Lookout      CA  50.10  -91.92     26.60        58          75
# 7         Avarua      CK -21.21 -159.78     75.20        73          49
# 8       Phonhong      LA  18.50  102.42     72.41        79          93
# 9           Hilo      US  19.73 -155.09     82.40        74          40
#
#    Wind Speed Current Description
# 0        6.31       moderate rain
# 1        0.43           clear sky
# 2        8.05    scattered clouds
# 3        6.17           clear sky
# 4       20.80    scattered clouds
# 5       17.22                mist
# 6        6.93       broken clouds
# 7       11.41          light rain
# 8        1.63     overcast clouds
# 9        5.82    scattered clouds

# %%
# Export to csv
city_data_df.to_csv("WeatherPy_Database.csv", index_label="City ID")
